# %% [markdown]
# Python Operator Precedence (Numerical)
# 1. 15 // 2 ** 2 % 3 + 12 ^ 45 >> 2 & 19 | 8 < 5
# 2. (28 & 15) << 2 + 1 ^ 84 // 4 % 3
# 3. 100 >> 2 == 25 & 14 | 3
# 4. (~15) + (18 ^ 24) >> 2 & 7
# 5. 5 * 4 // 3 % 2 ** 2 + 14 << 1 ^ 19 & 11
# 6. 56 // 3 % 4 * 2 ** 3 + 18 ^ 25 >> 2 & 144 // 12 | 7 < 12

# %%
5 * 4 // 3 % 2 ** 2 + 14 << 1 ^ 19 & 11
# Out:
# 35

# %%
56 // 3 % 4 * 2 ** 3 + 18 ^ 25 >> 2 & 144 // 12 | 7 < 12
# Out:
# False

# %%
(~15) + (18 ^ 24) >> 2 & 7
# Out:
# 6

# %%
(28 & 15) << 2 + 1 ^ 84 // 4 % 3
# Out:
# 96

# %%
100 >> 2 == 25 & 14 | 3
# Out:
# False

# %%
15 // 2 ** 2 % 3 + 12 ^ 45 >> 2 & 19 | 8 < 5
# Out:
# False

# %% [markdown]
# Python Magic (Dunder) Methods Assignment
# Instructions: Implement each required magic method in the specified class. Write clean Python
# code, create appropriate objects to test your implementation, and display the output to verify that
# each method works correctly.
#
# Question 1: __init__, __str__, and __setitem__
# Create a Student class with attributes name, roll_no, and marks. Implement __init__ to initialize
# values, __str__ to print the object in a readable format, and __setitem__ to update attributes using
# dictionary-style syntax such as student['marks']=90. Demonstrate each method.

# %%
# Q1: __init__, __str__, and __setitem__

class Student:
    def __init__(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks

    def __str__(self):
        return f"Name: {self.name}, Roll No: {self.roll_no}, Marks: {self.marks}"

    def __setitem__(self, key, value):
        setattr(self, key, value)

    def __eq__(self, other):
        return self.roll_no == other.roll_no


student1 = Student("Sushma", 101, 85)


student1["marks"] = 90
student1["roll_no"] = 100
print("After updating marks and roll number:")

print(student1)
# Out:
# After updating marks and roll number:
# Name: Sushma, Roll No: 100, Marks: 90

# %% [markdown]
# Question 2: __add__
# Create a Vector class representing a 2D vector (x, y). Implement __add__ so two vectors can be
# added using the + operator. Print the resulting vector.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 5)

result = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Result:", result)


# ===========================
# Out:
# Vector 1: (2, 3)
# Vector 2: (4, 5)
# Result: (6, 8)

# %% [markdown]
# Question 3: __eq__
# Implement __eq__ in the Student class so two students are equal if they have the same roll
# number. Test the comparison with different objects.

# %%
student2 = Student("Ram", 101, 75)
student3 = Student("Hari", 102, 90)


print("student1 == student2:", student1 == student2)
print("student1 == student3:", student1 == student3)
# Out:
# student1 == student2: False
# student1 == student3: False

# %% [markdown]
# Question 4: __len__ and __getitem__
# Create a Playlist class that stores a list of songs. Implement __len__ to return the total number of
# songs and __getitem__ to access songs using indexing.

# %%
class Playlist:
    def __init__(self, songs):
        self.songs = songs

    def __len__(self):
        return len(self.songs)

    def __getitem__(self, index):
        return self.songs[index]


playlist = Playlist(["Song A", "Song B", "Song C", "Song D"])

print("Total songs:", len(playlist))
print("First song:", playlist[0])
print("Third song:", playlist[2])
# Out:
# Total songs: 4
# First song: Song A
# Third song: Song C

# %% [markdown]
# Question 5: __call__
# Create a Multiplier class that accepts a number in the constructor. Implement __call__ so the object
# behaves like a function and returns the multiplication result.

# %%
class Multiplier:
    def __init__(self, number):
        self.number = number

    def __call__(self, value):
        return self.number * value


multiply = Multiplier(5)

print("5 x 10 =", multiply(10))
print("5 x 7 =", multiply(7))
# Out:
# 5 x 10 = 50
# 5 x 7 = 35

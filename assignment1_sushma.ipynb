# %% [markdown]
# Python String Methods
# Submitted By- Sushma Karki

# %%
print("the sky is high above.".capitalize())
#capitalize the first chatracter of the string
# Out:
# The sky is high above.

# %%
'ABCD'.lower()
# Out:
# 'abcd'

# %%
'abcD'.upper()
# Out:
# 'ABCD'

# %%
'hello World, K chha?'.title()
# Out:
# 'Hello World, K Chha?'

# %%
"hello World, K chha?".casefold()
# Out:
# 'hello world, k chha?'

# %%
print('love'.center(10, '*'))
print('love'.center(10, '-'))
print('love'.center(10, '3'))
# Out:
# ***love***
# ---love---
# 333love333

# %%
'meow'.ljust(6,'-')
# Out:
# 'meow--'

# %%
'meow'.rjust(6,'-')
# Out:
# '--meow'

# %%
'  meow '.strip()
# Out:
# 'meow'

# %%
'  meow'.lstrip()
# Out:
# 'meow'

# %%
'meow  '.rstrip()
# Out:
# 'meow'

# %%
"hippopotamus".count('p')
# Out:
# 3

# %%
'monkey'.encode()
# Out:
# b'monkey'

# %%
print("monkey".endswith('y'))
print('monkey'.endswith('c'))
# Out:
# True
# False

# %%
#expandtabs()
'file\t tab pachiko strings'.expandtabs(10)
# Out:
# 'file       tab pachiko strings'

# %%
"metor shower".find('o')
# Out:
# 3

# %%
print("Hello {}".format('Sushma'))
# Out:
# Hello Sushma

# %%
#format_map()
print('{fruit}'.format_map({'fruit': 'apple'}))
# Out:
# apple

# %%
'helloeee'.index('e')
# Out:
# 1

# %%
'adadn9889u'.isalnum()
# Out:
# True

# %%
'ncjherfc893hru!&'.isalnum()
# Out:
# False

# %%
'd23e23'.isalpha()
# Out:
# False

# %%
'dsff'.isalpha()
# Out:
# True

# %%
'13123123'.isdecimal()
# Out:
# True

# %%
"13123321.99".isdecimal()
# Out:
# False

# %%
'1232324'.isdigit()
# Out:
# True

# %%
'variable_1'.isidentifier()
#identifier is name given to user defined item like variable, functions, object,class etc
# Out:
# True

# %%
'ADASF'.islower()
# Out:
# False

# %%
'dasd'.islower()
# Out:
# True

# %%
'cedcDFWF'.islower()
# Out:
# False

# %%
'ADDD'.isupper()
# Out:
# True

# %%
'23423.34'.isnumeric()
# Out:
# False

# %%
'2342334'.isnumeric()
# Out:
# True

# %%
'joon-tara'.isprintable()
# Out:
# True

# %%
" ".isspace()
# Out:
# False

# %%
"Our Earth".istitle()
# Out:
# False

# %%
'-'.join(['roll no', '21'])
# Out:
# 'roll no-21'

# %%
str.maketrans('rfr','bff')
# Out:
# {114: 102, 102: 102}

# %%
'apple=fruit'.partition('=')
#splits at first separator
# Out:
# ('apple', '=', 'fruit')

# %%
'apple=mango=banana'.rpartition('=')
#splits at last separator
# Out:
# ('apple=mango', '=', 'banana')

# %%
'unhappy'.removeprefix('un')
# Out:
# 'happy'

# %%
'potato cracker'.removesuffix('cracker')
# Out:
# 'potato '

# %%
'hello'.replace('ello', 'ey')
# Out:
# 'hey'

# %%
'hi'.replace('i','o')
# Out:
# 'ho'

# %%
'potato'.rfind('o')
# Out:
# 5

# %%
'potato'.find('o')
# Out:
# 1

# %%
'potato'.rindex('t')
# Out:
# 4

# %%
('abcd').split('b',1)
# Out:
# ['a', 'cd']

# %%
'my name is sushma'.split()
# Out:
# ['my', 'name', 'is', 'sushma']

# %%
'monkey'.startswith('mo')
# Out:
# True

# %%
'monkey'.endswith('m')
# Out:
# False

# %%
'AAAbbCa'.swapcase()
# Out:
# 'aaaBBcA'

# %%
'abcdef'.translate(str.maketrans('d','e'))
# Out:
# 'abceef'

# %%
'10'.zfill(10)
# Out:
# '0000000010'
